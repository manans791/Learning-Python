# %% [markdown]
# ## MatplotLib Tutorial

# %% [markdown]
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.

# %% [raw]
# *Generally easy to get started for simple plots
# *Support for custom labels and texts
# *Great control of every element in a figure
# *High-quality output in many formats
# *Very customizable in general

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
## simple Examples

#x=np.arange(40,50)
#y=np.arange(50,60)

# %%
## plotting using matplotlib

## plt scatter

plt.scatter(x,y,c='g')   # plt.scatter(x co-ordinate , y co-ordinate, c color)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('First-Plot')
plt.savefig('Test.png')

# %%
y=x*x

# %%
## plot

plt.plot(x,y,'r*',linestyle='dashed',linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
## creating sub-plots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
x=np.arange(1,11)
y=3*x+5
plt.plot(x,y)
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption")
# Out:
# Text(0, 0.5, 'y axis caption')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve 
x=np.arange(0,4*np.pi,0.1)  ## np.arange(start value , end value , step size)
y=np.sin(x)
plt.title('Sine Wave Form')
plt.plot(x,y)

# %%
#Subplot()
# Compute the x and y coordinates for points on sine and cosine curves 
x = np.arange(0, 5 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)  
   
# Set up a subplot grid that has height 2 and width 1, 
# and set the first such subplot as active. 
plt.subplot(2, 1, 1)
   
# Make the first plot 
plt.plot(x, y_sin,'r--') 
plt.title('Sine')  
   
# Set the second subplot as active, and make the second plot. 
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos,'g--') 
plt.title('Cosine')  
   
# Show the figure. 
plt.show()

# %%
# Bar plot

x=[2,8,10]
y=[11,16,9]

x2=[3,9,11]
y2=[6,15,7]
plt.bar(x2,y2)
plt.bar(x,y)

plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')
# Out:
# Text(0.5, 0, 'X axis')

# %%
## Histograms

a=np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a,)
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %% [markdown]
# ## Box Plot using Matplotlib

# %%
data=[np.random.normal(0,std,100) for std in range(1,4)]

# %%
plt.boxplot(data,patch_artist=True,vert=True)   #patch_artist give solor , vert is if you want it horizontal or horizontal
plt.title('Box-plot')
# Out:
# Text(0.5, 1.0, 'Box-plot')

# %% [markdown]
# ## Piechart

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode=(0.1,0,0,0)

plt.pie(sizes,explode,labels,)
# Out:
# ([<matplotlib.patches.Wedge at 0x24724674d30>,
# ...
#  [Text(0.7971028918998828, 0.8970100220871804, 'Python'),
#   Text(-0.64656382751384, 0.8899186574910392, 'C++'),
#   Text(-0.94900779332915, -0.5562231640272972, 'Ruby'),
#   Text(0.7466808503372186, -0.8077547324155322, 'Java')])
